# %%
# import library for reading dataset

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('weatherAUS.csv')

# %%
df
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1     2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2     2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3     2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4     2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# ...          ...      ...      ...      ...       ...          ...       ...
# 8420  2017-06-21    Uluru      2.8     23.4       0.0          NaN       NaN
# 8421  2017-06-22    Uluru      3.6     25.3       0.0          NaN       NaN
# 8422  2017-06-23    Uluru      5.4     26.9       0.0          NaN       NaN
# 8423  2017-06-24    Uluru      7.8     27.0       0.0          NaN       NaN
# 8424  2017-06-25    Uluru     14.9      NaN       0.0          NaN       NaN
#
# ...

# %%
# check for data types

# %%
df.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %%
# some columns are in object type, some in float type

# %%
# check for null values

# %%
df.isna().sum()
# Out:
# Date                0
# Location            0
# MinTemp            75
# MaxTemp            60
# Rainfall          240
# Evaporation      3512
# Sunshine         3994
# WindGustDir       991
# WindGustSpeed     991
# WindDir9am        829
# WindDir3pm        308
# WindSpeed9am       76
# WindSpeed3pm      107
# Humidity9am        59
# Humidity3pm       102
# Pressure9am      1309
# Pressure3pm      1312
# Cloud9am         2421
# Cloud3pm         2455
# Temp9am            56
# Temp3pm            96
# RainToday         240
# RainTomorrow      239
# dtype: int64

# %%
# lots of null values are present

# %%
# import encoder for encoding required columns

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lab_enc = LabelEncoder()

# %%
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
df['Location'].unique()
# Out:
# array(['Albury', 'CoffsHarbour', 'Newcastle', 'Penrith', 'Williamtown',
#        'Wollongong', 'Melbourne', 'Brisbane', 'Adelaide', 'PerthAirport',
#        'Darwin', 'Uluru'], dtype=object)

# %%
df['Location'] = lab_enc.fit_transform(df['Location'])

# %%
df['MinTemp'].unique()
# Out:
# array([13.4,  7.4, 12.9,  9.2, 17.5, 14.6, 14.3,  7.7,  9.7, 13.1, 15.9,
#        12.6,  8.4,  9.8, 14.1, 13.5, 11.2, 11.5, 17.1, 20.5, 15.3, 16.2,
#        16.9, 20.1, 19.7, 12.5, 12. , 11.3,  9.6, 10.5, 12.3, 13.7, 16.1,
#        14. , 17. , 17.3, 17.2, 17.4, 19.8, 14.9, 13.9, 18.6, 19.3, 24.4,
#        18.8, 20.8, 15.7, 18.5, 20.4, 21.8, 22.3, 22. , 28. , 21.5, 21.7,
#        23.5, 28.3, 18.4, 12.4, 13.3, 18. , 18.7, 15.5,  8.9, 15. , 15.4,
#        16. , 12.8, 13.2, 13.8,  7.6,  8.3, 11. , 20.9, 16.4, 10. ,  8.8,
#         9.3, 14.4, 10.8, 10.1,  9.1, 10.4, 12.2, 10.7,  7.8,  8.1,  7.5,
#         8.2, 11.6, 13. ,  9.9,  3.5,  6.6,  7. ,  5.7,  6.2,  6. , 10.6,
#         8.6,  4.5,  5.4,  2.1,  1.8,  7.2,  4.6,  4.2,  5.2,  4.1,  3.2,
#         4.3,  3.7,  3.6,  6.9, 10.3,  3. ,  2.6,  5.1,  4.4,  4.7,  6.7,
#         8. ,  2.2,  1.7,  2.8,  9. ,  6.3, -2. , -1.3,  2. ,  0.5,  1.2,
#         0.6,  0.9,  5. ,  3.9,  3.4,  0. , -1.5, -1.7, -0.4,  0.1,  4.8,
# ...

# %%
df['MinTemp'].mean()
# Out:
# 13.193305389221573

# %%
df['MinTemp'] = df['MinTemp'].fillna(df['MinTemp'].mean())

# %%
df['MinTemp'].isna().sum()
# Out:
# 0

# %%
df['MaxTemp'].unique()
# Out:
# array([22.9, 25.1, 25.7, 28. , 32.3, 29.7, 25. , 26.7, 31.9, 30.1, 30.4,
#        21.7, 18.6, 21. , 24.6, 27.7, 20.9, 22.5, 25.6, 29.3, 33. , 31.8,
#        30.9, 32.4, 33.9, 32.7, 27.2, 24.2, 24.4, 26.5, 23.9, 28.8, 34.6,
#        35.8, 37.9, 38.9, 28.3, 28.4, 30.8, 32. , 34.7, 37.7, 43. , 32.2,
#        36.6, 39.9, 38.1, 34. , 35.2, 30.6, 34.3, 38.4, 38.2, 40.7, 41.5,
#        42.9, 42.7, 43.1, 38.3, 36.9, 41.2, 42.2, 44.8, 40.2, 31.2, 27.3,
#        21.6, 29. , 29.2, 31.3, 31.1, 29.1, 31.7, 33.2, 29.6, 32.6, 34.5,
#        30.3, 22.1, 22. , 24. , 27.9, 30.2, 30.5, 25.8, 27. , 19.7, 21.9,
#        25.3, 33.5, 33.6, 30. , 31.6, 22.3, 29.8, 27.6, 28.9, 29.9, 32.1,
#        28.1, 21.4, 24.9, 25.4, 20. , 23.4, 22.7, 16.2, 15.8, 12.9, 11.5,
#        14.5, 12.2, 16.5, 17. , 19.2, 18.9, 19.1, 18.8, 19.3, 18.4, 19. ,
#        20.5, 19.5, 17.7, 18.5, 15.1, 16.3, 16.6, 16.4, 15.6, 19.8, 21.1,
#        20.3, 18.1, 15.7, 16.8, 17.1, 14.3, 13.4, 17.4, 16.1, 10.5, 11.6,
# ...

# %%
df['MaxTemp'].mean()
# Out:
# 23.85997609085473

# %%
df['MaxTemp'] = df['MaxTemp'].fillna(df['MaxTemp'].mean())

# %%
df['MaxTemp'].isna().sum()
# Out:
# 0

# %%
df['Rainfall'].mean()
# Out:
# 2.8059132559560473

# %%
df['Rainfall'] = df['Rainfall'].fillna(df['Rainfall'].mean())

# %%
df['Evaporation'].unique()
# Out:
# array([  nan,   8.6,   3.8,   2.8,   3.2,   6.8,   4.2,   1.6,   4.4,
#          4. ,   2.2,   3.4,   6.4,   4.6,   3.6,   4.8,   3. ,   1.2,
#          1.4,   2.6,   1. ,   2. ,   8.4,   2.4,   0.6,   5.4,   1.8,
#          7. ,   0.8,   0.2,   5.2,   5. ,   6. ,   7.6,   5.8,   5.6,
#          8. ,   6.2,   6.6,   7.8,   8.8,   7.4,   9.4,   7.2,   0.4,
#          0. ,  18. ,  24.2,  14.6,  19.4,  10.8,  28. ,  11.8,  24.6,
#         11.2,  22.6,  10. ,  37. ,  26. ,  11. ,  19.8,  24.4,  10.6,
#         27.4,  12. ,  11.6,  24. ,   9. ,  23. ,  29.2,  20.6,  13.2,
#         22.8,   9.8,  16. ,  20. ,  10.4,   9.6,  12.2,  15.4,  18.4,
#         24.8,  20.8,  32. ,  55.4,  17.8,  16.2,  14.2,  59.2,  33.8,
#         10.2, 145. ,  16.6,  47. ,  15.2,  15.8,  12.6,  11.4,   9.2,
#         14.8,  13. ,   8.2,  13.6,  12.8,  12.4,  17.6,  19.2,  13.8,
#         22.4,  18.6,  13.4,  17. ,  14. ,  14.4,  15. ,  15.6,   0.7])

# %%
df['Evaporation'].mean()
# Out:
# 5.389395481375942

# %%
df['Evaporation'] = df['Evaporation'].fillna(df['Evaporation'].mean())

# %%
df['Evaporation'].isna().sum()
# Out:
# 0

# %%
df['Sunshine'].unique()
# Out:
# array([ nan,  9. ,  3.4,  6.1, 11. ,  7.1,  2.8,  6.7,  6.4,  6. ,  9.4,
#         6.3, 11.1, 11.2, 11.4,  9.7,  7.9,  0.3,  0. ,  0.5,  3.5,  1.9,
#         1.1,  7.8,  8.8,  1.8,  6.6,  3.1,  3. , 10.4, 10.5,  9.9,  9.5,
#         1. ,  4.3,  9.2,  9.8,  4.8,  8.9,  4.5,  2.6, 10. , 10.2,  9.1,
#         2.2,  0.4,  0.7,  0.2,  2.7,  8.5,  3.6,  2.5,  6.9,  8.2,  6.8,
#         7.2,  9.6,  5.1,  5.8,  1.6,  0.6,  7.7,  8.3,  2.9,  8.4,  4.2,
#         9.3,  4.7,  4.1,  5.3,  7.4,  7.3,  2.4, 10.6, 10.3, 10.1,  2.3,
#        10.7,  8.6,  5.2, 10.9, 10.8,  8. ,  1.5,  8.7, 11.3, 11.5,  5.7,
#        11.9,  3.3, 12.1, 12.4,  7. ,  4. , 11.7, 12.7, 12.5, 12.6, 13. ,
#         5.5, 12.2, 11.6, 12.9, 13.1,  5.4,  3.7, 12. ,  2. ,  8.1, 13.2,
#        13.6, 12.3, 11.8,  7.5,  6.2,  1.2,  3.8,  1.4,  5. ,  0.8,  4.4,
#         6.5,  0.1,  4.9,  3.9,  4.6,  0.9,  5.9,  7.6,  1.3, 12.8, 13.4,
#         1.7, 13.3,  3.2,  2.1, 13.5, 13.8, 13.9, 13.7,  5.6])

# %%
df['Sunshine'].mean()
# Out:
# 7.6322049198826525

# %%
df['Sunshine'] = df['Sunshine'].fillna(df['Sunshine'].mean())

# %%
df['WindGustDir'].unique()
# Out:
# array(['W', 'WNW', 'WSW', 'NE', 'NNW', 'N', 'NNE', 'SW', nan, 'ENE',
#        'SSE', 'S', 'NW', 'SE', 'ESE', 'E', 'SSW'], dtype=object)

# %%
df['WindGustDir'] = lab_enc.fit_transform(df['WindGustDir'])

# %%
df['WindGustSpeed'].unique()
# Out:
# array([ 44.,  46.,  24.,  41.,  56.,  50.,  35.,  80.,  28.,  30.,  31.,
#         61.,  nan,  22.,  63.,  43.,  26.,  33.,  57.,  48.,  39.,  37.,
#         52.,  98.,  54.,  83.,  59.,  70.,  69.,  17.,  20.,  19.,  15.,
#         13.,  11.,  72.,  85.,  65.,  78., 107.,  74.,  67.,  94.,  76.,
#         81.,  87.,   9.,  93.,   7.,  91.,  89., 102., 100.])

# %%
df['WindGustSpeed'].mean()
# Out:
# 40.174468657519505

# %%
df['WindGustSpeed'] = df['WindGustSpeed'].fillna(df['WindGustSpeed'].mean())

# %%
df['WindGustSpeed'].isna().sum()
# Out:
# 0

# %%
df['WindDir9am'].unique()
# Out:
# array(['W', 'NNW', 'SE', 'ENE', 'SW', 'SSE', 'S', 'NE', nan, 'SSW', 'N',
#        'WSW', 'ESE', 'E', 'NW', 'WNW', 'NNE'], dtype=object)

# %%
df['WindDir9am'] = lab_enc.fit_transform(df['WindDir9am'])

# %%
df['WindDir3pm'].unique()
# Out:
# array(['WNW', 'WSW', 'E', 'NW', 'W', 'SSE', 'ESE', 'ENE', 'NNW', 'SSW',
#        'SW', 'SE', 'N', 'S', 'NNE', nan, 'NE'], dtype=object)

# %%
df['WindDir3pm'] = lab_enc.fit_transform(df['WindDir3pm'])

# %%
df['WindSpeed9am'].unique()
# Out:
# array([20.,  4., 19., 11.,  7.,  6., 15., 17., 28., 24., nan,  9.,  0.,
#        13.,  2., 26., 30., 22., 35., 37., 31., 33., 43., 41., 46., 39.,
#        56., 54., 50., 52., 44., 61., 57., 48., 63.])

# %%
df['WindSpeed9am'].mean()
# Out:
# 13.847646424721523

# %%
df['WindSpeed9am'] = df['WindSpeed9am'].fillna(df['WindSpeed9am'].mean())

# %%
df['WindSpeed9am'].isna().sum()
# Out:
# 0

# %%
df['WindSpeed3pm'].unique()
# Out:
# array([24., 22., 26.,  9., 20., 17., 28., 11.,  6., 13., 30., 19., 31.,
#         7., 15., 48.,  4., 33.,  0.,  2., nan, 37., 46., 39., 50., 35.,
#        41., 44., 43., 65., 56., 83., 54., 61., 57., 52.])

# %%
df['WindSpeed3pm'].mean()
# Out:
# 18.533661937965856

# %%
df['WindSpeed3pm'] = df['WindSpeed3pm'].fillna(df['WindSpeed3pm'].mean())

# %%
df['WindSpeed3pm'].isna().sum()
# Out:
# 0

# %%
df['Humidity9am'].unique()
# Out:
# array([ 71.,  44.,  38.,  45.,  82.,  55.,  49.,  48.,  42.,  58.,  89.,
#         76.,  65.,  57.,  50.,  69.,  80.,  47.,  56.,  54.,  41.,  78.,
#         46.,  43.,  33.,  34.,  36.,  52.,  51.,  40.,  35.,  39.,  60.,
#         37.,  27.,  32.,  53.,  20.,  66.,  63.,  62.,  87.,  61.,  59.,
#         92.,  72.,  67.,  75.,  88.,  68.,  73.,  74.,  83.,  77.,  70.,
#         81.,  86.,  97.,  99.,  91.,  85.,  93.,  84.,  94.,  79.,  98.,
#         96.,  95.,  90.,  64.,  29.,  21., 100.,  30.,  23.,  nan,  31.,
#         22.,  28.,  25.,  16.,  19.,  17.,  18.,  14.,  10.,  12.,  11.,
#         24.,  26.,  15.])

# %%
df['Humidity9am'].mean()
# Out:
# 67.82249581639971

# %%
df['Humidity9am'] = df['Humidity9am'].fillna(df['Humidity9am'].mean())

# %%
df['Humidity9am'].isna().sum()
# Out:
# 0

# %%
df['Humidity3pm'].unique()
# Out:
# array([22., 25., 30., 16., 33., 23., 19.,  9., 27., 91., 93., 43., 32.,
#        28., 82., 65., 26., 24., 17., 15., 70., 12.,  8., 31., 20., 10.,
#        21., 39., 13., 11., 69., 18., 14., 35., 90., 68., 74., 41., 34.,
#        78., 49., 37., 42., 47., 52., 29., 86., 89., 62., 79., 48., 46.,
#        38., 44., 51., 36., 45., 40., 53., 61., 59., 63., 54., 57., 50.,
#        58., 75., 97., 80., 95., 56., 72., 60., 71., 73., 81., 76., 64.,
#        87., 85., 67., 55., 77., 84.,  7., 99., 92., 66., 83., 94., 96.,
#        88., nan, 98.,  6.])

# %%
df['Humidity3pm'].mean()
# Out:
# 51.2497897392767

# %%
df['Humidity3pm'] = df['Humidity3pm'].fillna(df['Humidity3pm'].mean())

# %%
df['Humidity3pm'].isna().sum()
# Out:
# 0

# %%
df['Pressure9am'].unique()
# Out:
# array([1007.7, 1010.6, 1007.6, 1017.6, 1010.8, 1009.2, 1009.6, 1013.4,
#        1008.9, 1007. , 1011.8, 1010.5,  994.3, 1001.2, 1009.7, 1012.2,
#        1005.8, 1009.4, 1019.2, 1019.3, 1013.6, 1007.8, 1011. , 1012.9,
#        1010.9, 1006.8, 1005.2, 1004.8, 1005.6, 1006.1, 1004.5, 1014.4,
#        1018.7, 1015.1, 1012.6, 1011.9, 1017.8, 1009.9, 1014.1, 1015.7,
#        1011.6, 1008.4, 1019.7, 1015.8, 1010.1, 1005.3, 1007.9, 1005.4,
#        1016.5, 1017.7, 1014.9, 1014.6, 1014.2, 1012.5, 1011.7, 1008.8,
#        1005.9, 1008. , 1008.2, 1009.3, 1012.8, 1017. , 1023.3, 1022.5,
#        1016.2, 1017.2, 1012.4, 1015.6, 1013. , 1014. , 1016.6, 1007.5,
#        1014.7, 1014.5, 1013.7, 1015.2, 1019.5, 1021.3, 1017.4, 1012.7,
#        1013.3, 1016.3, 1014.8, 1019.1, 1023. , 1023.8, 1022.4, 1023.2,
#        1022.6, 1018.8, 1019.8, 1020.4, 1021.8, 1026.7, 1027.1, 1024.2,
#        1021.5, 1024.4, 1024.1, 1018.5, 1022.8, 1022.7, 1023.6, 1025.2,
# ...

# %%
df['Pressure9am'].mean()
# Out:
# 1017.6402332771205

# %%
df['Pressure9am'] = df['Pressure9am'].fillna(df['Pressure9am'].mean())

# %%
df['Pressure9am'].isna().sum()
# Out:
# 0

# %%
df['Pressure3pm'].unique()
# Out:
# array([1007.1, 1007.8, 1008.7, 1012.8, 1006. , 1005.4, 1008.2, 1010.1,
#        1003.6, 1005.7, 1004.2,  993. , 1001.8, 1010.3, 1010.4, 1002.2,
#        1009.7, 1017.1, 1014.8, 1008.1, 1007.6, 1001.7, 1003.4, 1005.1,
#        1003.2, 1013.1, 1009.2, 1006.7, 1002.7, 1010.9, 1013.7, 1006.8,
#        1012.1, 1006.9, 1012.7, 1017.4, 1016.2, 1010.6, 1004.8, 1005.9,
#         997.8, 1003.9, 1014.6, 1014.1, 1011.6, 1011.8, 1010.2, 1010.5,
#        1007.4, 1004.7, 1002.6, 1005. , 1003.8, 1006.5, 1008.5, 1011.1,
#        1017.3, 1019.7, 1016.4, 1013.8, 1013.5, 1007.5, 1004.5, 1010.8,
#        1012.4, 1013.4, 1015. , 1012.6, 1004.6, 1009. , 1012. , 1014.7,
#        1015.9, 1018. , 1018.9, 1008. , 1013.2, 1013.9, 1013.6, 1014.4,
#        1019.2, 1017.2, 1020.7, 1020.6, 1019.1, 1019.5, 1019.4, 1018.4,
#        1012.9, 1019.3, 1016.5, 1019.6, 1023.5, 1023.4, 1017.7, 1020.3,
#        1020.8, 1018.7, 1009.8, 1016.8, 1020. , 1020.9, 1021.6, 1015.7,
# ...

# %%
df['Pressure3pm'].mean()
# Out:
# 1015.2360747926323

# %%
df['Pressure3pm'] = df['Pressure3pm'].fillna(df['Pressure3pm'].mean())

# %%
df['Pressure3pm'].isna().sum()
# Out:
# 0

# %%
df['Cloud9am'].unique()
# Out:
# array([ 8., nan,  7.,  1.,  0.,  5.,  4.,  2.,  6.,  3.])

# %%
df['Cloud9am'].mean()
# Out:
# 4.566622251832112

# %%
df['Cloud9am'] = df['Cloud9am'].fillna(df['Cloud9am'].mean())

# %%
df['Cloud9am'].isna().sum()
# Out:
# 0

# %%
df['Cloud3pm'].unique()
# Out:
# array([nan,  2.,  8.,  7.,  1.,  5.,  4.,  6.,  3.,  0.])

# %%
df['Cloud3pm'].mean()
# Out:
# 4.5031825795644895

# %%
df['Cloud3pm'] = df['Cloud3pm'].fillna(df['Cloud3pm'].mean())

# %%
df['Cloud3pm'].isna().sum()
# Out:
# 0

# %%
df['Temp9am'].unique()
# Out:
# array([16.9, 17.2, 21. , 18.1, 17.8, 20.6, 16.3, 18.3, 20.1, 20.4, 15.9,
#        17.4, 15.8, 17.3, 18. , 15.5, 19.1, 24.5, 23.8, 20.9, 21.5, 23.2,
#        26.6, 24.6, 21.6, 12.5, 19.7, 14.9, 17.1, 20.7, 22.4, 23.1, 25.2,
#        17.9, 20.2, 22.8, 24.2, 24.3, 25.6, 27.6, 16. , 22. , 26.8, 27.3,
#        26.1, 23.3, 21.2, 23.4, 25.8, 28.2, 29. , 29.2, 29.9, 32.4, 28.8,
#        27.2, 25.5, 26.5, 28.7, 29.6, 34.5, 18.7, 16.7, 17. , 19.2, 21.4,
#        22.1, 19.3, 15. , 20. , 22.2, 23. , 15.6, 13.9, 12.6, 13.3, 17.6,
#        18.6, 19. , 19.9, 12.7, 12.2, 12.1, 14.7, 18.8, 15.4, 16.2, 16.5,
#        14. , 16.6, 18.4, 12.9, 13.8, 15.1, 16.4, 16.1, 20.5,  9.6, 12.4,
#        14.1, 11.2,  9.5,  7.6, 10.1,  8.2,  7.9,  7.2, 10.6, 10.3, 10. ,
#         8.3, 11. ,  9.4, 11.7,  8.5,  9.1,  7.5, 13. ,  7. ,  8.8,  7.4,
#        11.9, 11.6, 13.6,  7.1, 10.2,  8. ,  9.2, 11.3,  4.7,  6.8,  4.9,
#         2.2,  1.9,  5.9,  6.5,  5.4,  6.6,  5.6,  6.9,  8.4,  9.8, 13.5,
# ...

# %%
df['Temp9am'].mean()
# Out:
# 17.762014577607847

# %%
df['Temp9am'] = df['Temp9am'].fillna(df['Temp9am'].mean())

# %%
df['Temp9am'].isna().sum()
# Out:
# 0

# %%
df['Temp3pm'].unique()
# Out:
# array([21.8, 24.3, 23.2, 26.5, 29.7, 28.9, 24.6, 25.5, 30.2, 28.2, 28.8,
#        17. , 15.8, 19.8, 23.5, 26.2, 18.1, 21.5, 21. , 27.3, 31.6, 30.8,
#        29. , 31.2, 33. , 32.1, 26.1, 18.2, 22.7, 25.7, 22.1, 33.9, 34.4,
#        36.8, 38.4, 27.6, 26.6, 29.3, 30. , 33.2, 35.7, 41.5, 27.1, 25.8,
#        30.5, 37.7, 36.1, 33.1, 36.5, 36.2, 39.2, 40.1, 41.2, 42. , 41.9,
#        37.1, 35.2, 39.7, 41.6, 43.4, 38.5, 29.4, 24.9, 17.3, 28.5, 29.2,
#        29.5, 27. , 30.7, 32.7, 26.8, 29.8, 31.3, 33.4, 28.6, 33.6, 28.1,
#        21.9, 21.4, 22. , 29.6, 18.8, 23.8, 19.7, 18.3, 20.5, 23.9, 27.2,
#        32.6, 33.5, 31.4, 19.6, 27.7, 29.9, 30.9, 27.4, 20.3, 21.2, 20.9,
#        21.6, 25. , 24.4, 23.1, 18.9, 19.4, 22.9, 23.6, 21.3, 22.3, 22.6,
#        15.1, 14.5, 11.6,  9.4, 14. , 12.1, 16.1, 16.3, 19.1, 18.5, 18.4,
#        19.2, 20.2, 17.7, 18. , 14.6, 15.3, 15.9, 14.7, 18.7, 21.7, 20.8,
#        19.5, 17.4, 15.6, 16.7, 16.8, 13.4, 13. , 16.5, 10.2, 11.5, 11.4,
# ...

# %%
df['Temp3pm'].mean()
# Out:
# 22.442934325849407

# %%
df['Temp3pm'] = df['Temp3pm'].fillna(df['Temp3pm'].mean())

# %%
df['Temp3pm'].isnull().sum()
# Out:
# 0

# %%
df['RainToday'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df['RainToday'].mode()
# Out:
# 0    No
# Name: RainToday, dtype: object

# %%
df['RainToday'] = df['RainToday'].replace(np.nan,'No')

# %%
df['RainToday'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['RainToday'] = lab_enc.fit_transform(df['RainToday'])

# %%
df['RainTomorrow'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df['RainTomorrow'].mode()
# Out:
# 0    No
# Name: RainTomorrow, dtype: object

# %%
df['RainTomorrow'] = df['RainTomorrow'].replace(np.nan,'No')

# %%
df['RainTomorrow'] = lab_enc.fit_transform(df['RainTomorrow'])

# %%
# after encoding the required columns and fillinf the null values

# %%
# check again for nulls, present or filled over

# %%
df.isna().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %%
# no nulls remain

# %%
# check datatype either changes or not

# %%
df.dtypes
# Out:
# Date              object
# Location           int32
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir        int32
# WindGustSpeed    float64
# WindDir9am         int32
# WindDir3pm         int32
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday          int32
# RainTomorrow       int32
# dtype: object

# %%
# datatype changes

# %%
# one column named Date is present in dataset is only like nominal data

# %%
# delete the Date column

# %%
df = df.drop(columns='Date')

# %%
df
# Out:
#       Location  MinTemp    MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0            1     13.4  22.900000       0.6     5.389395  7.632205
# 1            1      7.4  25.100000       0.0     5.389395  7.632205
# 2            1     12.9  25.700000       0.0     5.389395  7.632205
# 3            1      9.2  28.000000       0.0     5.389395  7.632205
# 4            1     17.5  32.300000       1.0     5.389395  7.632205
# ...        ...      ...        ...       ...          ...       ...
# 8420         9      2.8  23.400000       0.0     5.389395  7.632205
# 8421         9      3.6  25.300000       0.0     5.389395  7.632205
# 8422         9      5.4  26.900000       0.0     5.389395  7.632205
# 8423         9      7.8  27.000000       0.0     5.389395  7.632205
# 8424         9     14.9  23.859976       0.0     5.389395  7.632205
#
#       WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  ...  Humidity9am  \
# ...

# %%
# importing libraries for visualization

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# first distribution plot to check the trend of dataset

# %%
plt.figure(figsize=(20,15),facecolor='yellow')
plotnumber=1

for column in df:
    if plotnumber <= 24:
        ax = plt.subplot(6,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=15)
        
    plotnumber+=1
    
plt.show()

# %%
# some data left skewed some data right skewed and some data seems in bell shape

# %%
# boxplot for outliers

# %%
plt.figure(figsize=(20,15),facecolor='yellow')
plotnumber=1

for column in df:
    if plotnumber<=24:
        ax = plt.subplot(6,4,plotnumber)
        plt.boxplot(df[column])
        plt.xlabel(column,fontsize=15)
        
    plotnumber+=1
    
plt.show()

# %%
# some outliers are shown

# %%
# finding quanties and inter quantile range to checking outliers individually for each columns

# %%
q1 = df.quantile(0.25)


q3 = df.quantile(0.75)


iqr = q3 - q1

# %%
print(q1)
# Out:
# Location            3.000000
# MinTemp             9.300000
# MaxTemp            19.300000
# Rainfall            0.000000
# Evaporation         4.000000
# Sunshine            7.632205
# WindGustDir         4.000000
# WindGustSpeed      31.000000
# WindDir9am          4.000000
# WindDir3pm          4.000000
# WindSpeed9am        6.000000
# WindSpeed3pm       11.000000
# Humidity9am        56.000000
# Humidity3pm        39.000000
# Pressure9am      1014.000000
# Pressure3pm      1011.400000
# Cloud9am            3.000000
# Cloud3pm            3.000000
# Temp9am            13.800000
# Temp3pm            18.100000
# RainToday           0.000000
# RainTomorrow        0.000000
# Name: 0.25, dtype: float64

# %%
print(q3)
# Out:
# Location            8.000000
# MinTemp            17.300000
# MaxTemp            28.000000
# Rainfall            1.400000
# Evaporation         5.389395
# Sunshine            8.900000
# WindGustDir        13.000000
# WindGustSpeed      48.000000
# WindDir9am         13.000000
# WindDir3pm         12.000000
# WindSpeed9am       20.000000
# WindSpeed3pm       24.000000
# Humidity9am        80.000000
# Humidity3pm        63.000000
# Pressure9am      1021.300000
# Pressure3pm      1018.800000
# Cloud9am            7.000000
# Cloud3pm            7.000000
# Temp9am            21.900000
# Temp3pm            26.300000
# RainToday           0.000000
# RainTomorrow        0.000000
# Name: 0.75, dtype: float64

# %%
print(iqr)
# Out:
# Location          5.000000
# MinTemp           8.000000
# MaxTemp           8.700000
# Rainfall          1.400000
# Evaporation       1.389395
# Sunshine          1.267795
# WindGustDir       9.000000
# WindGustSpeed    17.000000
# WindDir9am        9.000000
# WindDir3pm        8.000000
# WindSpeed9am     14.000000
# WindSpeed3pm     13.000000
# Humidity9am      24.000000
# Humidity3pm      24.000000
# Pressure9am       7.300000
# Pressure3pm       7.400000
# Cloud9am          4.000000
# Cloud3pm          4.000000
# Temp9am           8.100000
# Temp3pm           8.200000
# RainToday         0.000000
# RainTomorrow      0.000000
# dtype: float64

# %%
df.columns
# Out:
# Index(['Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
l_high = (q3.Location + (1.5 * iqr.Location))
l_high
# Out:
# 15.5

# %%
index = np.where(df['Location'] > l_high)
index
# Out:
# (array([], dtype=int64),)

# %%
l_low = (q1.Location - (1.5 * iqr.Location))
l_low
# Out:
# -4.5

# %%
index = np.where(df['Location'] < l_low)
index
# Out:
# (array([], dtype=int64),)

# %%
mn_high = (q3.MinTemp + (1.5 * iqr.MinTemp))
mn_high
# Out:
# 29.3

# %%
index = np.where(df['MinTemp'] > mn_high)
index
# Out:
# (array([], dtype=int64),)

# %%
mn_low = (q1.MinTemp - (1.5 * iqr.MinTemp))
mn_low
# Out:
# -2.6999999999999993

# %%
index = np.where(df['MinTemp'] < mn_low)
index
# Out:
# (array([], dtype=int64),)

# %%
mt_high = (q3.MaxTemp + (1.5 * iqr.MaxTemp))
mt_high
# Out:
# 41.05

# %%
index = np.where(df['MaxTemp'] > mt_high)
index
# Out:
# (array([  44,   59,   60,   61,   62,   66,   67,   68,  405,  406,  407,
#          417, 2527, 2859, 3271, 3277, 3278, 3284, 3291, 3301, 3302, 3711,
#         4123, 4129, 4130, 4136, 4143, 4153, 4154, 4618, 4972, 5429, 5783,
#         6994, 7326, 7983, 7984], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (8388, 22)

# %%
mt_low = (q1.MaxTemp - (1.5 * iqr.MaxTemp))
mt_low
# Out:
# 6.250000000000002

# %%
index = np.where(df['MaxTemp'] < mt_low)
index
# Out:
# (array([], dtype=int64),)

# %%
r_high = (q3.Rainfall + (1.5 * iqr.Rainfall))
r_high
# Out:
# 3.4999999999999996

# %%
index = np.where(df['Rainfall'] > r_high)
index
# Out:
# (array([  12,   13,   17, ..., 8335, 8341, 8346], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (7046, 22)

# %%
r_low = (q1.Rainfall - (1.5 * iqr.Rainfall))
r_low
# Out:
# -2.0999999999999996

# %%
index = np.where(df['Rainfall'] < r_low)
index
# Out:
# (array([], dtype=int64),)

# %%
ev_high = (q3.Evaporation + (1.5 * iqr.Evaporation))
ev_high
# Out:
# 7.473488703439855

# %%
index = np.where(df['Evaporation'] > ev_high)
index
# Out:
# (array([ 927,  937,  941,  972,  977,  979,  982,  991,  994, 1001, 1016,
#         1024, 1027, 1043, 1239, 2348, 2360, 2363, 2370, 2372, 2376, 2377,
#         2378, 2383, 2385, 2388, 2389, 2392, 2395, 2398, 2402, 2404, 2406,
#         2410, 2412, 2417, 2418, 2420, 2422, 2428, 2429, 2431, 2436, 2437,
#         2438, 2439, 2442, 2450, 2451, 2453, 2456, 2457, 2468, 2475, 2481,
#         2485, 2500, 2504, 2506, 2507, 2511, 2518, 2519, 2525, 2529, 2536,
#         2543, 2548, 2555, 2572, 2577, 2579, 2588, 2595, 2600, 2605, 2612,
#         2624, 2626, 2631, 2637, 2638, 2641, 2646, 2648, 2649, 2659, 2660,
#         2671, 2672, 2673, 2674, 2677, 2678, 2698, 2699, 2705, 2709, 3046,
#         3058, 3061, 3068, 3070, 3074, 3075, 3076, 3081, 3083, 3086, 3087,
#         3090, 3093, 3096, 3100, 3102, 3104, 3108, 3110, 3115, 3116, 3118,
#         3120, 3126, 3127, 3129, 3134, 3135, 3136, 3137, 3140, 3148, 3149,
#         3151, 3154, 3155, 3166, 3173, 3179, 3183, 3198, 3202, 3204, 3205,
# ...

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (6108, 22)

# %%
ev_low = (q1.Evaporation - (1.5 * iqr.Evaporation))
ev_low
# Out:
# 1.9159067779360868

# %%
index = np.where(df['Evaporation'] < ev_low)
index
# Out:
# (array([ 771,  784,  797,  801,  802,  808,  815,  816,  817,  821,  822,
#          823,  824,  825,  826,  827,  828,  830,  831,  832,  833,  834,
#          835,  836,  837,  838,  839,  840,  841,  842,  846,  848,  850,
#          851,  854,  855,  857,  858,  864,  865,  868,  873,  892,  923,
#          933,  937, 1038, 1067, 1075, 1099, 1103, 1104, 1111, 1114, 1116,
#         1117, 1118, 1120, 1121, 1122, 1123, 1124, 1127, 1128, 1129, 1131,
#         1133, 1134, 1136, 1138, 1143, 1151, 1152, 1157, 1173, 1174, 1187,
#         1188, 1192, 1223, 2408, 2430, 2464, 2472, 2487, 2492, 2500, 2528,
#         3023, 3045, 3079, 3087, 3102, 3107, 3115, 3143, 3570, 3658, 3663,
#         3671, 3673, 3676, 3678, 3685, 3686, 3687, 3688, 3690, 3694, 3695,
#         3697, 3698, 3700, 3701, 3702, 3703, 3704, 3705, 3707, 3710, 3711,
#         3713, 3714, 3715, 3716, 3717, 3718, 3720, 3721, 3722, 3724, 3726,
#         3728, 3729, 3730, 3731, 3732, 3733, 3734, 3739, 3741, 3743, 3744,
# ...

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (5572, 22)

# %%
ss_high = (q3.Sunshine + (1.5 * iqr.Sunshine))
ss_high
# Out:
# 10.801692620176022

# %%
index = np.where(df['Sunshine'] > ss_high)
index
# Out:
# (array([ 767,  776,  777,  778,  779,  866,  868,  869,  870,  877,  880,
#          881,  883,  884,  885,  886,  889,  890,  892,  893,  895,  897,
#          898,  906,  907,  908,  909,  912,  913,  914,  917,  920,  921,
#          922,  924,  925,  926,  929,  931,  932,  937,  938,  939,  943,
#          944,  952,  955,  956,  957,  959,  961,  962,  964,  965,  966,
#          967,  968,  969,  970,  977,  978,  980,  981,  983,  986, 1001,
#         1002, 1007, 1008, 1016, 1132, 1133, 1134, 1137, 1139, 1141, 1144,
#         1147, 2243, 2256, 2257, 2262, 2263, 2266, 2267, 2268, 2285, 2286,
#         2294, 2295, 2296, 2302, 2305, 2316, 2317, 2318, 2323, 2850, 2863,
#         2864, 2869, 2870, 2873, 2874, 2875, 2892, 2893, 2901, 2902, 2903,
#         2909, 2912, 2923, 2924, 2925, 2930, 3465, 3467, 3469, 3470, 3477,
#         3478, 3480, 3483, 3485, 3486, 3488, 3493, 3494, 3496, 3497, 3498,
#         3499, 3500, 3503, 3505, 3506, 3507, 3508, 3509, 3512, 3517, 3518,
# ...

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (5054, 22)

# %%
ss_low = (q1.Sunshine - (1.5 * iqr.Sunshine))
ss_low
# Out:
# 5.73051229970663

# %%
index = np.where(df['Sunshine'] < ss_low)
index
# Out:
# (array([ 769,  777,  778,  783,  789,  790,  801,  802,  803,  806,  808,
#          812,  814,  834,  839,  844,  851,  856,  859,  869,  880,  884,
#          885,  887,  888,  893,  894,  896,  897,  899,  902,  903,  904,
#          905,  906,  912,  914,  921,  923,  924,  925,  926,  927,  930,
#          933,  937,  943,  947,  948,  949,  952,  959,  967,  978,  980,
#          990,  991,  996, 1003, 1007, 1008, 1026, 1037, 1040, 1043, 1048,
#         1049, 1056, 1057, 1058, 1061, 1067, 2174, 2208, 2229, 2230, 2239,
#         2256, 2762, 2796, 2817, 2818, 2827, 2844, 3343, 3344, 3345, 3351,
#         3353, 3355, 3359, 3363, 3364, 3365, 3367, 3376, 3377, 3381, 3384,
#         3385, 3386, 3393, 3394, 3398, 3402, 3403, 3404, 3406, 3407, 3408,
#         3416, 3417, 3418, 3419, 3421, 3422, 3425, 3426, 3428, 3429, 3430,
#         3431, 3432, 3433, 3434, 3435, 3437, 3438, 3439, 3440, 3443, 3444,
#         3445, 3447, 3449, 3452, 3454, 3455, 3459, 3460, 3462, 3463, 3464,
# ...

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (4489, 22)

# %%
wgr_high = (q3.WindGustDir + (1.5 * iqr.WindGustDir))
wgr_high
# Out:
# 26.5

# %%
index = np.where(df['WindGustDir'] > wgr_high)
index
# Out:
# (array([], dtype=int64),)

# %%
wgr_low = (q1.WindGustDir - (1.5 * iqr.WindGustDir))
wgr_low
# Out:
# -9.5

# %%
index = np.where(df['WindGustDir'] < wgr_low)
index
# Out:
# (array([], dtype=int64),)

# %%
wgs_high = (q3.WindGustSpeed + (1.5 * iqr.WindGustSpeed))
wgs_high
# Out:
# 73.5

# %%
index = np.where(df['WindGustSpeed'] > wgs_high)
index
# Out:
# (array([   8,   47,  222,  299,  303,  322,  631,  674,  951, 1713, 1826,
#         1831, 1845, 1852, 1872, 1885, 2190, 2202, 2208, 2217, 2219, 2228,
#         2232, 2239, 2242, 2277, 2288, 2308, 2327, 2384, 2410, 2487, 2518,
#         2526, 2543, 2600, 2601, 2619, 2620, 2625, 2638, 2639, 2772, 2784,
#         2790, 2799, 2801, 2810, 2814, 2821, 2824, 2859, 2870, 2890, 2909,
#         2966, 2992, 3069, 3100, 3108, 3125, 3182, 3183, 3201, 3202, 3207,
#         3220, 3221, 3258, 3261, 3283, 3306, 3401, 3409, 3411, 3436, 3439,
#         3442, 3464, 3487, 3582, 3590, 3592, 3617, 3962, 4066], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (4403, 22)

# %%
wgs_low = (q1.WindGustSpeed - (1.5 * iqr.WindGustSpeed))
wgs_low
# Out:
# 5.5

# %%
index = np.where(df['WindGustSpeed'] < wgs_low)
index
# Out:
# (array([], dtype=int64),)

# %%
wd9a_high = (q3.WindDir9am + (1.5 * iqr.WindDir9am))
wd9a_high
# Out:
# 26.5

# %%
index = np.where(df['WindDir9am'] > wd9a_high)
index
# Out:
# (array([], dtype=int64),)

# %%
wd9a_low = (q1.WindDir9am - (1.5 * iqr.WindDir9am))
wd9a_low
# Out:
# -9.5

# %%
index = np.where(df['WindDir9am'] < wd9a_low)
index
# Out:
# (array([], dtype=int64),)

# %%
wd3p_high = (q3.WindDir3pm + (1.5 * iqr.WindDir3pm))
wd3p_high
# Out:
# 24.0

# %%
index = np.where(df['WindDir3pm'] > wd3p_high)
index
# Out:
# (array([], dtype=int64),)

# %%
wd3p_low = (q1.WindDir3pm - (1.5 * iqr.WindDir3pm))
wd3p_low
# Out:
# -8.0

# %%
index = np.where(df['WindDir3pm'] < wd3p_low)
index
# Out:
# (array([], dtype=int64),)

# %%
ws9a_high = (q3.WindSpeed9am + (1.5 * iqr.WindSpeed9am))
ws9a_high
# Out:
# 41.0

# %%
index = np.where(df['WindSpeed9am'] > ws9a_high)
index
# Out:
# (array([1003, 1321, 1360, 1411, 1461, 1544, 1568, 2249, 2260, 2454, 2585,
#         2805, 2816, 3010, 3141, 3251, 3306, 3311, 3314, 3315, 3324, 3335,
#         3338, 3346, 3424, 3479, 3484, 3487, 3488, 3497, 3508, 3511, 3519],
#        dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (4370, 22)

# %%
ws9a_low = (q1.WindSpeed9am - (1.5 * iqr.WindSpeed9am))
ws9a_low
# Out:
# -15.0

# %%
index = np.where(df['WindSpeed9am'] < ws9a_low)
index
# Out:
# (array([], dtype=int64),)

# %%
ws3p_high = (q3.WindSpeed3pm + (1.5 * iqr.WindSpeed3pm))
ws3p_high
# Out:
# 43.5

# %%
index = np.where(df['WindSpeed3pm'] > ws3p_high)
index
# Out:
# (array([ 844, 1046, 1084, 1094, 1097, 1100, 1120, 1121, 1315, 1419, 1433,
#         1453, 1570, 1632, 2276, 2354, 2444, 2453, 2465, 2474, 2580, 2619,
#         2828, 2906, 2996, 3005, 3017, 3026, 3132, 3171, 3180, 3276, 3344,
#         3440], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (4336, 22)

# %%
ws3p_low = (q1.WindSpeed3pm - (1.5 * iqr.WindSpeed3pm))
ws3p_low
# Out:
# -8.5

# %%
index = np.where(df['WindSpeed3pm'] < ws3p_low)
index
# Out:
# (array([], dtype=int64),)

# %%
h9a_high = (q3.Humidity9am + (1.5 * iqr.Humidity9am))
h9a_high
# Out:
# 116.0

# %%
index = np.where(df['Humidity9am'] > h9a_high)
index
# Out:
# (array([], dtype=int64),)

# %%
h9a_low = (q1.Humidity9am - (1.5 * iqr.Humidity9am))
h9a_low
# Out:
# 20.0

# %%
index = np.where(df['Humidity9am'] < h9a_low)
index
# Out:
# (array([3820, 3821, 3830, 3836, 3850, 3963], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (4330, 22)

# %%
h3p_high = (q3.Humidity3pm + (1.5 * iqr.Humidity3pm))
h3p_high
# Out:
# 99.0

# %%
index = np.where(df['Humidity3pm'] > h3p_high)
index
# Out:
# (array([], dtype=int64),)

# %%
h3p_low = (q1.Humidity3pm - (1.5 * iqr.Humidity3pm))
h3p_low
# Out:
# 3.0

# %%
index = np.where(df['Humidity3pm'] < h3p_low)
index
# Out:
# (array([], dtype=int64),)

# %%
p9a_high = (q3.Pressure9am + (1.5 * iqr.Pressure9am))
p9a_high
# Out:
# 1032.25

# %%
index = np.where(df['Pressure9am'] > p9a_high)
index
# Out:
# (array([ 156,  386,  387,  472,  473,  478,  479,  480,  490,  504,  505,
#          508,  509,  723, 2171, 2172, 2173, 2191, 2560, 2715, 2716, 2717,
#         2735, 3104, 3192, 3195, 3268, 3269, 3270, 3354, 3357, 3430, 3431,
#         3432, 3743, 3744, 3745, 3757, 3759, 3765, 3766, 3767, 3770, 3771,
#         3772, 3916, 3917, 3918, 3919, 3920, 3983, 3984, 3985, 4076, 4089,
#         4097], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (4274, 22)

# %%
p9a_low = (q1.Pressure9am - (1.5 * iqr.Pressure9am))
p9a_low
# Out:
# 1003.0500000000001

# %%
index = np.where(df['Pressure9am'] < p9a_low)
index
# Out:
# (array([ 259,  612,  643,  688, 2219, 2288, 2292, 2308, 2425, 2563, 2758,
#         2827, 2831, 2847, 2964, 3102, 3275, 3432, 3898], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (4255, 22)

# %%
p3p_high = (q3.Pressure3pm + (1.5 * iqr.Pressure3pm))
p3p_high
# Out:
# 1029.8999999999999

# %%
index = np.where(df['Pressure3pm'] > p3p_high)
index
# Out:
# (array([ 383,  467,  705,  921, 2381, 2382, 2914, 2915, 4022], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (4246, 22)

# %%
p3p_low = (q1.Pressure3pm - (1.5 * iqr.Pressure3pm))
p3p_low
# Out:
# 1000.3

# %%
index = np.where(df['Pressure3pm'] < p3p_low)
index
# Out:
# (array([ 258, 2096, 2234, 2410, 2627, 2765, 2941, 3180, 3336, 3427, 3692],
#        dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (4235, 22)

# %%
c9a_high = (q3.Cloud9am + (1.5 * iqr.Cloud9am))
c9a_high
# Out:
# 13.0

# %%
index = np.where(df['Cloud9am'] > c9a_high)
index
# Out:
# (array([], dtype=int64),)

# %%
c9a_low = (q1.Cloud9am - (1.5 * iqr.Cloud9am))
c9a_low
# Out:
# -3.0

# %%
index = np.where(df['Cloud9am'] < c9a_low)
index
# Out:
# (array([], dtype=int64),)

# %%
c3p_high = (q3.Cloud3pm + (1.5 * iqr.Cloud3pm))
c3p_high
# Out:
# 13.0

# %%
index = np.where(df['Cloud3pm'] > c3p_high)
index
# Out:
# (array([], dtype=int64),)

# %%
c3p_low = (q1.Cloud3pm - (1.5 * iqr.Cloud3pm))
c3p_low
# Out:
# -3.0

# %%
index = np.where(df['Cloud3pm'] < c3p_low)
index
# Out:
# (array([], dtype=int64),)

# %%
t9a_high = (q3.Temp9am + (1.5 * iqr.Temp9am))
t9a_high
# Out:
# 34.05

# %%
index = np.where(df['Temp9am'] > t9a_high)
index
# Out:
# (array([54], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (4234, 22)

# %%
t9a_low = (q1.Temp9am - (1.5 * iqr.Temp9am))
t9a_low
# Out:
# 1.650000000000004

# %%
index = np.where(df['Temp9am'] < t9a_low)
index
# Out:
# (array([], dtype=int64),)

# %%
t3p_high = (q3.Temp3pm + (1.5 * iqr.Temp3pm))
t3p_high
# Out:
# 38.6

# %%
index = np.where(df['Temp3pm'] > t3p_high)
index
# Out:
# (array([  50,  291,  644, 1786, 1792, 2047, 2071, 2263, 2264, 2575, 2599,
#         2791, 2792], dtype=int64),)

# %%
df = df.drop(df.index[index])

# %%
df.shape
# Out:
# (4221, 22)

# %%
t3p_low = (q1.Temp3pm - (1.5 * iqr.Temp3pm))
t3p_low
# Out:
# 5.8000000000000025

# %%
index = np.where(df['Temp3pm'] < t3p_low)
index
# Out:
# (array([], dtype=int64),)

# %%
rt_high = (q3.RainToday + (1.5 * iqr.RainToday))
rt_high
# Out:
# 0.0

# %%
index = np.where(df['RainToday'] > rt_high)
index
# Out:
# (array([   8,   10,   24,   57,   83,   85,   96,  122,  140,  154,  155,
#          158,  169,  173,  184,  196,  208,  210,  211,  216,  219,  220,
#          223,  240,  242,  248,  249,  256,  294,  303,  311,  332,  372,
#          402,  403,  420,  427,  459,  463,  464,  472,  485,  492,  502,
#          504,  508,  509,  517,  518,  521,  559,  562,  565,  566,  573,
#          579,  590,  592,  596,  605,  625,  626,  643,  697,  715,  717,
#          730,  734,  745,  761,  773,  805,  807,  832,  833,  836,  844,
#          848,  864,  895,  904,  913,  970,  971,  975,  982, 1010, 1033,
#         1060, 1093, 1097, 1099, 1107, 1175, 1176, 1177, 1183, 1200, 1204,
#         1207, 1209, 1210, 1237, 1243, 1264, 1277, 1300, 1303, 1316, 1328,
#         1329, 1330, 1338, 1352, 1373, 1383, 1412, 1418, 1423, 1449, 1450,
#         1458, 1467, 1470, 1483, 1490, 1491, 1492, 1510, 1530, 1541, 1547,
#         1574, 1578, 1579, 1582, 1584, 1605, 1612, 1621, 1639, 1646, 1653,
# ...

# %%
rt_low = (q1.RainToday - (1.5 * iqr.RainToday))
rt_low
# Out:
# 0.0

# %%
index = np.where(df['RainToday'] < rt_low)
index
# Out:
# (array([], dtype=int64),)

# %%
# removed a lot of outliers

# %%
# checking the data shape

# %%
df.shape
# Out:
# (4221, 22)

# %%
# a lot of data lost

# %%
df
# Out:
#       Location  MinTemp    MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0            1     13.4  22.900000       0.6     5.389395  7.632205
# 1            1      7.4  25.100000       0.0     5.389395  7.632205
# 2            1     12.9  25.700000       0.0     5.389395  7.632205
# 3            1      9.2  28.000000       0.0     5.389395  7.632205
# 4            1     17.5  32.300000       1.0     5.389395  7.632205
# ...        ...      ...        ...       ...          ...       ...
# 8420         9      2.8  23.400000       0.0     5.389395  7.632205
# 8421         9      3.6  25.300000       0.0     5.389395  7.632205
# 8422         9      5.4  26.900000       0.0     5.389395  7.632205
# 8423         9      7.8  27.000000       0.0     5.389395  7.632205
# 8424         9     14.9  23.859976       0.0     5.389395  7.632205
#
#       WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  ...  Humidity9am  \
# ...

# %%
# let's plot again ditribution plot

# %%
plt.figure(figsize=(20,15),facecolor='yellow')
plotnumber=1

for column in df:
    if plotnumber <= 24:
        ax = plt.subplot(6,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=15)
        
    plotnumber+=1
    
plt.show()

# %%
# now data is looking some in normal shape

# %%
plt.figure(figsize=(20,15),facecolor='yellow')
plotnumber=1

for column in df:
    if plotnumber <= 24:
        ax = plt.subplot(6,4,plotnumber)
        plt.boxplot(df[column])
        plt.xlabel(column,fontsize=15)
        
    plotnumber+=1
    
plt.show()

# %%
# heatmap to check relation between columns

# %%
corr = df.corr().abs()

# %%
plt.figure(figsize=(20,15))

sns.heatmap(corr, annot=True)
plt.show()

# %%
# some column seem like highly related to each other

# %%
# scatter plot to check relation between columns

# %%
plt.scatter(df.Pressure9am,df.Pressure3pm)
plt.xlabel('Pressure9am')
plt.ylabel('Pressure3pm')

plt.show()

# %%
plt.scatter(df.Temp9am,df.Temp3pm)
plt.xlabel('Temp9am')
plt.ylabel('Temp3pm')

plt.show()

# %%
plt.scatter(df.MinTemp,df.MaxTemp)

plt.xlabel('MinTemp')
plt.ylabel('MaxTemp')

plt.show()

# %%
# above graphs show that these columns are highly related

# %%
plt.scatter(df.Rainfall,df.RainToday)

plt.xlabel('Rainfall')
plt.ylabel('RainToday')

plt.show()

# %%
# let's delete these columns

# %%
df = df.drop(columns='Temp9am')

# %%
df = df.drop(columns='Pressure9am')

# %%
df = df.drop(columns='MaxTemp')

# %%
# again plotting heatmap

# %%
corr = df.corr().abs()

plt.figure(figsize=(30,20))

sns.heatmap(corr, annot=True)

plt.show()

# %%
# now it is looking normal

# %%
# split data in two variables

# %%
x = df.drop(columns='RainTomorrow')

y = df['RainTomorrow']

# %%
# standard scaler to standardize the data

# %%
# train test split

# %%
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score,classification_report

# %%
scaler = StandardScaler()

x_scaled = scaler.fit_transform(x)

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.25,random_state=100)

# %%
# Because first we consider, it will be rainfall or not , so it is classification problem

# %%
# import Classification Model

# %%
# first Logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr_pred = lr.predict(x_test)

# %%
accuracy = accuracy_score(y_test,lr_pred)
accuracy
# Out:
# 0.8607954545454546

# %%
print(classification_report(y_test,lr_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92       900
#            1       0.59      0.19      0.29       156
#
#     accuracy                           0.86      1056
#    macro avg       0.73      0.58      0.61      1056
# weighted avg       0.83      0.86      0.83      1056

# %%
# second Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_pred = dt.predict(x_test)

# %%
accuracy = accuracy_score(y_test,dt_pred)
accuracy
# Out:
# 0.8626893939393939

# %%
print(classification_report(y_test,dt_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92       900
#            1       0.53      0.56      0.55       156
#
#     accuracy                           0.86      1056
#    macro avg       0.73      0.74      0.73      1056
# weighted avg       0.87      0.86      0.86      1056

# %%
# third random forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rf_pred = rf.predict(x_test)

# %%
accuracy = accuracy_score(y_test,rf_pred)
accuracy
# Out:
# 0.9100378787878788

# %%
print(classification_report(y_test,rf_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95       900
#            1       0.92      0.43      0.59       156
#
#     accuracy                           0.91      1056
#    macro avg       0.91      0.71      0.77      1056
# weighted avg       0.91      0.91      0.90      1056

# %%
# fourth support vector machine

# %%
from sklearn.svm import SVC

# %%
svc = SVC()

svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
svc_pred = svc.predict(x_test)

# %%
accuracy = accuracy_score(y_test,svc_pred)
accuracy
# Out:
# 0.8712121212121212

# %%
print(classification_report(y_test,svc_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93       900
#            1       0.76      0.19      0.30       156
#
#     accuracy                           0.87      1056
#    macro avg       0.82      0.59      0.61      1056
# weighted avg       0.86      0.87      0.84      1056

# %%
# check for each model how these perform on training and test data

# %%
# plotting roc_curve

# %%
from sklearn.metrics import plot_roc_curve,roc_curve

# %%
disp = plot_roc_curve(lr,x_train,y_train)
plot_roc_curve(dt,x_train,y_train,ax=disp.ax_)
plot_roc_curve(rf,x_train,y_train,ax=disp.ax_)
plot_roc_curve(svc,x_train,y_train,ax=disp.ax_)

plt.show()

# %%
disp = plot_roc_curve(lr,x_test,y_test)
plot_roc_curve(dt,x_test,y_test,ax=disp.ax_)
plot_roc_curve(rf,x_test,y_test,ax=disp.ax_)
plot_roc_curve(svc,x_test,y_test,ax=disp.ax_)

plt.show()

# %%
# All models are performing well and good,

#  consider decision tree because it is performing well and there is no problem of overfitting

# %%
# saving model

# %%
import pickle

# %%
pickle.dump(dt,open('dt_cl_Rain-Pred','wb'))

# %%
# now again predict for how much rainfall, so it is regression problem

# %%
df
# Out:
#       Location  MinTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0            1     13.4       0.6     5.389395  7.632205           13
# 1            1      7.4       0.0     5.389395  7.632205           14
# 2            1     12.9       0.0     5.389395  7.632205           15
# 3            1      9.2       0.0     5.389395  7.632205            4
# 4            1     17.5       1.0     5.389395  7.632205           13
# ...        ...      ...       ...          ...       ...          ...
# 8420         9      2.8       0.0     5.389395  7.632205            0
# 8421         9      3.6       0.0     5.389395  7.632205            6
# 8422         9      5.4       0.0     5.389395  7.632205            3
# 8423         9      7.8       0.0     5.389395  7.632205            9
# 8424         9     14.9       0.0     5.389395  7.632205           16
#
#       WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# ...

# %%
a = df.drop(columns='Rainfall')
b = df['Rainfall']

# %%
a_scaled = scaler.fit_transform(a)

# %%
a_train,a_test,b_train,b_test = train_test_split(a_scaled,b,test_size=0.25,random_state=100)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
# first model Linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lr1 = LinearRegression()

lr1.fit(a_train,b_train)
# Out:
# LinearRegression()

# %%
lr1_pred = lr1.predict(a_test)

# %%
lr1.score(a_train,b_train)
# Out:
# 0.5463094970007117

# %%
lr1.score(a_test,b_test)
# Out:
# 0.5317406952625107

# %%
mean_absolute_error(b_test,lr1_pred)
# Out:
# 0.2811088652268984

# %%
mean_squared_error(b_test,lr1_pred)
# Out:
# 0.285947560140104

# %%
np.sqrt(mean_squared_error(b_test,lr1_pred))
# Out:
# 0.5347406475480464

# %%
# second model DecisionTree

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt1 = DecisionTreeRegressor()

dt1.fit(a_train,b_train)
# Out:
# DecisionTreeRegressor()

# %%
dt1_pred = dt1.predict(a_test)

# %%
dt1.score(a_train,b_train)
# Out:
# 0.9826560265316513

# %%
dt1.score(a_test,b_test)
# Out:
# 0.5724773643904503

# %%
mean_absolute_error(b_test,dt1_pred)
# Out:
# 0.18335235737799568

# %%
mean_squared_error(b_test,dt1_pred)
# Out:
# 0.2610712767912887

# %%
np.sqrt(mean_squared_error(b_test,dt1_pred))
# Out:
# 0.510951344837538

# %%
# third model RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf1 = RandomForestRegressor()

rf1.fit(a_train,b_train)
# Out:
# RandomForestRegressor()

# %%
rf1_pred = rf.predict(a_test)

# %%
rf1.score(a_train,b_train)
# Out:
# 0.9476445395988458

# %%
rf1.score(a_test,b_test)
# Out:
# 0.7359196120968996

# %%
mean_absolute_error(b_test,rf1_pred)
# Out:
# 0.20945570899793522

# %%
mean_squared_error(b_test,rf1_pred)
# Out:
# 0.16159785486448786

# %%
np.sqrt(mean_squared_error(b_test,rf1_pred))
# Out:
# 0.4019923567239654

# %%
# fourth support vector machine

# %%
from sklearn.svm import SVR

# %%
svr = SVR()

svr.fit(a_train,b_train)
# Out:
# SVR()

# %%
svr_pred = svr.predict(a_test)

# %%
svr.score(a_train,b_train)
# Out:
# 0.6476258529799812

# %%
svr.score(a_test,b_test)
# Out:
# 0.5357747176985395

# %%
mean_absolute_error(b_test,svr_pred)
# Out:
# 0.2404017818091977

# %%
mean_squared_error(b_test,svr_pred)
# Out:
# 0.28348414112960607

# %%
np.sqrt(mean_squared_error(b_test,svr_pred))
# Out:
# 0.5324322878353698

# %%
# fifth Ada Boost

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
ada = AdaBoostRegressor()

ada.fit(a_train,b_train)
# Out:
# AdaBoostRegressor()

# %%
ada_pred = ada.predict(a_test)

# %%
ada.score(a_train,b_train)
# Out:
# 0.332592205571852

# %%
ada.score(a_test,b_test)
# Out:
# 0.24626354880415802

# %%
# models are performing in different manners

# %%
# let's do hyperparameter tuning to ada boost to improve its performance

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
params = {'n_estimators':[30,40,50,60],'learning_rate':[0.25,0.30,0.35,0.40]}

# %%
rnd_srch = RandomizedSearchCV(AdaBoostRegressor(),cv=5,param_distributions=params)

# %%
rnd_srch.fit(a_train,b_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=AdaBoostRegressor(),
#                    param_distributions={'learning_rate': [0.25, 0.3, 0.35, 0.4],
#                                         'n_estimators': [30, 40, 50, 60]})

# %%
rnd_srch.best_estimator_
# Out:
# AdaBoostRegressor(learning_rate=0.3)

# %%
ada = AdaBoostRegressor(learning_rate=0.4,n_estimators=40)

ada.fit(a_train,b_train)
# Out:
# AdaBoostRegressor(learning_rate=0.4, n_estimators=40)

# %%
ada_pred = ada.predict(a_test)

# %%
ada.score(a_train,b_train)
# Out:
# 0.5143476151904021

# %%
ada.score(a_test,b_test)
# Out:
# 0.4722787993229446

# %%
# from all above observations random forest is performing well than all others

# %%
# saving it

# %%
pickle.dump(rf1,open('rf_reg_Rain','wb'))
